# %%
from sklearn import model_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = load_diabetes(return_X_y=True)
X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.25)

# %%
def gb_predict(X, trees_list, eta):
    # Реализуемый алгоритм градиентного бустинга будет инициализироваться нулевыми значениями,
    # поэтому все деревья из списка trees_list уже являются дополнительными и при предсказании
    # прибавляются с шагом eta
    
#     predictions = np.zeros(X.shape[0])
#     for i, x in enumerate(X):
#         prediction = 0
#         for alg in trees_list:
#             prediction += eta * alg.predict([x])[0]
#         predictions[i] = prediction
        
    predictions = np.array(
        [sum([eta * alg.predict([x])[0] for alg in trees_list]) for x in X]
    )

    return predictions

# %% [markdown]
# В качестве функционала ошибки будем использовать среднеквадратичную ошибку. Реализуем соответствующую функцию.

# %%
def mean_squared_error(y_real, prediction):
    return (sum((y_real - prediction)**2)) / len(y_real)

# %% [markdown]
# Используем $L_{2}$ loss $L(y, z) = (y - z)^{2},$ ее производная по $z$ примет вид $L'(y, z) = 2(z - y)$. Реализуем ее также в виде функции (коэффициент 2 можно отбросить).

# %%
def residual(y, z):
    return - (z - y)

# %% [markdown]
# Реализуем функцию обучения градиентного бустинга.

# %%
def evaluate_alg(X_train, X_test, y_train, y_test, trees, eta):
    train_prediction = gb_predict(X_train, trees, eta)
    train_error = mean_squared_error(y_train, train_prediction)
    test_prediction = gb_predict(X_test, trees, eta)
    test_error = mean_squared_error(y_test, test_prediction)
    return train_error, test_error

# %%
def get_error_plot(train_err, test_err, x_name):
    plt.xlabel(x_name)
    plt.ylabel('MSE')
    plt.xlim(0, len(train_err))
    plt.plot(list(train_err.keys()), list(train_err.values()), label='train error')
    plt.plot(list(test_err.keys()), list(test_err.values()), label='test error')
    plt.legend(loc='upper right')
    plt.show()

# %%
def gb_fit(n_trees, max_depth, x_train, x_test, y_train, y_test, eta):

    # Деревья будем записывать в список
    trees = []

    # Будем записывать ошибки на обучающей и тестовой выборке на каждой итерации в список
    train_errors = []
    test_errors = []

    for i in range(n_trees):
        tree = DecisionTreeRegressor(max_depth=max_depth, random_state=42)

        # первый алгоритм просто обучаем на выборке и добавляем в список
        if len(trees) == 0:
            # обучаем первое дерево на обучающей выборке
            tree.fit(x_train, y_train)

            train_errors.append(mean_squared_error(y_train, gb_predict(x_train, trees, eta)))
            test_errors.append(mean_squared_error(y_test, gb_predict(x_test, trees, eta)))
        else:
            # Получим ответы на текущей композиции
            target = gb_predict(x_train, trees, eta)

            # алгоритмы начиная со второго обучаем на сдвиг
            tree.fit(x_train, residual(y_train, target))

            train_errors.append(mean_squared_error(y_train, gb_predict(x_train, trees, eta)))
            test_errors.append(mean_squared_error(y_test, gb_predict(x_test, trees, eta)))

        trees.append(tree)

    return trees, train_errors, test_errors

def calc_gb_fit_evaluate_alg(tree, depth):
    eta = 0.1
    trees, train_errors, test_errors = gb_fit(tree, depth, X_train, X_test, y_train, y_test, eta)
    train_error, test_error = evaluate_alg(X_train, X_test, y_train, y_test, trees, eta)
    print(f"tree={tree} depth={depth}")
    return train_error, test_error, tree, depth

# %%
from multiprocessing import Process, Value, Array


xxx = []
tree_count = 30
depth_count = 15

def multi_run_wrapper(args):
    return calc_gb_fit_evaluate_alg(*args)

for x, y in np.ndindex((tree_count, depth_count)):
    xxx.append((x +1, y + 1))

if __name__ == "__main__":
    from multiprocessing import Pool

    pool = Pool(20)
    result = pool.map(multi_run_wrapper,xxx)
    print(result)
# Out:
# tree=1 depth=7tree=1 depth=1tree=1 depth=13
#
#
# tree=1 depth=14
# tree=1 depth=2tree=1 depth=8
#
# tree=1 depth=15
# tree=1 depth=3tree=1 depth=9
#
# tree=2 depth=10
# tree=2 depth=4
# tree=1 depth=4
# tree=1 depth=10
# tree=1 depth=5
# tree=1 depth=11
# tree=1 depth=12tree=2 depth=1
#
# tree=1 depth=6
# tree=3 depth=1
# tree=2 depth=5tree=3 depth=13
#
# tree=2 depth=11
# tree=3 depth=7
# tree=2 depth=2
# tree=2 depth=6tree=2 depth=12
#
# tree=4 depth=10
# tree=4 depth=4
# tree=2 depth=3
# tree=2 depth=7
# tree=2 depth=13
# tree=3 depth=2
# tree=3 depth=14
# tree=3 depth=8
# tree=2 depth=8
# tree=2 depth=14
# tree=5 depth=7
# tree=5 depth=1
# tree=5 depth=13
# tree=2 depth=15
# tree=2 depth=9
# tree=3 depth=3
# tree=3 depth=15
# tree=3 depth=9
# tree=4 depth=5
# tree=4 depth=11
# tree=6 depth=4
# tree=6 depth=10
# tree=3 depth=4
# tree=3 depth=10
# tree=4 depth=1
# tree=3 depth=5
# tree=7 depth=1
# tree=7 depth=13
# tree=3 depth=11
# tree=7 depth=7tree=4 depth=6
#
# tree=5 depth=2tree=4 depth=12
# tree=5 depth=14
#
# tree=5 depth=8
# tree=3 depth=6
# tree=3 depth=12
# tree=4 depth=2
# tree=8 depth=4
# tree=8 depth=10
# tree=4 depth=7
# tree=4 depth=13
# tree=6 depth=5
# tree=6 depth=11
# tree=5 depth=3
# tree=5 depth=15
# tree=5 depth=9
# tree=4 depth=3
# tree=4 depth=8
# tree=4 depth=14
# tree=9 depth=7
# tree=9 depth=1
# tree=7 depth=2
# tree=9 depth=13
# tree=7 depth=14
# tree=4 depth=15
# tree=7 depth=8tree=5 depth=4
#
# tree=4 depth=9
# tree=5 depth=10
# tree=6 depth=6
# tree=6 depth=12
# tree=6 depth=1
# tree=5 depth=5
# tree=10 depth=4
# tree=8 depth=5
# tree=5 depth=11
# tree=8 depth=11
# tree=10 depth=10
# tree=7 depth=3
# tree=6 depth=7
# tree=6 depth=13
# tree=6 depth=2
# tree=7 depth=15
# tree=7 depth=9
# tree=5 depth=6
# tree=5 depth=12
# tree=9 depth=2
# tree=9 depth=8
# tree=11 depth=1
# tree=11 depth=7
# tree=9 depth=14
# tree=6 depth=8
# tree=6 depth=14
# tree=6 depth=3
# tree=7 depth=4
# tree=11 depth=13
# tree=7 depth=10
# tree=8 depth=12
# tree=6 depth=9
# tree=8 depth=6
# tree=6 depth=15
# tree=8 depth=1
# tree=10 depth=5
# tree=10 depth=11
# tree=12 depth=4
# tree=7 depth=5
# tree=12 depth=10
# tree=9 depth=9
# tree=9 depth=3
# tree=7 depth=11
# tree=9 depth=15
# tree=8 depth=13
# tree=8 depth=7
# tree=8 depth=2
# tree=7 depth=6
# tree=11 depth=2
# tree=11 depth=8
# tree=7 depth=12
# tree=13 depth=1
# tree=11 depth=14
# tree=10 depth=6
# tree=13 depth=7
# tree=9 depth=10
# tree=8 depth=14
# tree=10 depth=12
# tree=9 depth=4
# tree=8 depth=8
# tree=13 depth=13
# tree=8 depth=3
# tree=10 depth=1
# tree=12 depth=5
# tree=12 depth=11
# tree=8 depth=15
# tree=14 depth=4
# tree=9 depth=11
# tree=14 depth=10
# tree=11 depth=3
# tree=8 depth=9
# tree=9 depth=5
# tree=10 depth=7
# tree=11 depth=9
# tree=10 depth=13
# tree=11 depth=15
# tree=10 depth=2
# tree=13 depth=2
# tree=13 depth=8
# tree=9 depth=12
# tree=9 depth=6
# tree=15 depth=1
# tree=10 depth=8
# tree=13 depth=14
# tree=10 depth=14
# tree=11 depth=4tree=12 depth=6
#
# tree=12 depth=12
# tree=15 depth=7
# tree=11 depth=10
# tree=10 depth=3
# tree=12 depth=1
# tree=15 depth=13
# tree=14 depth=5
# tree=14 depth=11
# tree=10 depth=9
# tree=10 depth=15
# tree=16 depth=4
# tree=13 depth=9
# tree=11 depth=5
# tree=13 depth=3
# tree=11 depth=11
# tree=16 depth=10
# tree=12 depth=7
# tree=12 depth=13
# tree=13 depth=15
# tree=12 depth=2
# tree=15 depth=2
# tree=15 depth=8
# tree=11 depth=6
# tree=17 depth=1
# tree=11 depth=12
# tree=17 depth=7
# tree=14 depth=6
# tree=15 depth=14
# tree=14 depth=12
# tree=12 depth=8
# tree=13 depth=10
# tree=12 depth=14
# tree=13 depth=4
# tree=17 depth=13
# tree=12 depth=3
# tree=14 depth=1
# tree=16 depth=5
# tree=16 depth=11
# tree=18 depth=4
# tree=18 depth=10
# tree=12 depth=9
# tree=15 depth=3
# tree=12 depth=15
# tree=14 depth=7
# tree=13 depth=11
# tree=15 depth=9
# tree=14 depth=13
# tree=13 depth=5
# tree=15 depth=15
# tree=17 depth=2
# tree=17 depth=8
# tree=14 depth=2
# tree=17 depth=14
# tree=19 depth=1
# tree=13 depth=12
# tree=16 depth=6
# tree=19 depth=7
# tree=13 depth=6
# tree=16 depth=12
# tree=14 depth=8
# tree=15 depth=4
# tree=14 depth=14
# tree=15 depth=10
# tree=19 depth=13
# tree=18 depth=5
# tree=18 depth=11
# tree=14 depth=3
# tree=16 depth=1
# tree=17 depth=3
# tree=17 depth=9
# tree=20 depth=4
# tree=14 depth=9
# tree=20 depth=10
# tree=14 depth=15
# tree=16 depth=7
# tree=15 depth=5
# tree=17 depth=15
# tree=16 depth=13
# tree=15 depth=11
# tree=19 depth=2
# tree=16 depth=2
# tree=19 depth=8
# tree=21 depth=1
# tree=18 depth=6
# tree=18 depth=12
# tree=19 depth=14
# tree=21 depth=7
# tree=17 depth=4
# tree=15 depth=6
# tree=17 depth=10
# tree=15 depth=12
# tree=16 depth=8
# tree=16 depth=14
# tree=21 depth=13
# tree=18 depth=1
# tree=20 depth=5
# tree=20 depth=11
# tree=16 depth=3
# tree=22 depth=4
# tree=22 depth=10
# tree=18 depth=7
# tree=19 depth=3
# tree=18 depth=13
# tree=17 depth=5
# tree=19 depth=9
# tree=16 depth=9
# tree=17 depth=11
# tree=16 depth=15
# tree=19 depth=15
# tree=21 depth=2
# tree=21 depth=8
# tree=18 depth=2
# tree=23 depth=1tree=21 depth=14
#
# tree=23 depth=7
# tree=20 depth=6
# tree=20 depth=12
# tree=17 depth=6
# tree=18 depth=8
# tree=17 depth=12
# tree=18 depth=14
# tree=19 depth=4
# tree=19 depth=10
# tree=23 depth=13
# tree=22 depth=5
# tree=22 depth=11
# tree=20 depth=1
# tree=18 depth=3
# tree=21 depth=3
# tree=24 depth=4
# tree=21 depth=9
# tree=24 depth=10
# tree=18 depth=9
# tree=18 depth=15
# tree=20 depth=13
# tree=20 depth=7
# tree=21 depth=15
# tree=19 depth=5
# tree=19 depth=11
# tree=23 depth=2
# tree=23 depth=8
# tree=20 depth=2
# tree=22 depth=12
# tree=22 depth=6
# tree=23 depth=14
# tree=25 depth=1
# tree=25 depth=7
# tree=21 depth=4
# tree=21 depth=10
# tree=20 depth=14
# tree=20 depth=8
# tree=19 depth=6
# tree=25 depth=13
# tree=19 depth=12
# tree=24 depth=11
# tree=24 depth=5
# tree=22 depth=1
# tree=20 depth=3
# tree=23 depth=3
# tree=26 depth=4
# tree=23 depth=9
# tree=26 depth=10
# tree=22 depth=13
# tree=22 depth=7
# tree=21 depth=5
# tree=23 depth=15
# tree=21 depth=11
# tree=20 depth=15
# tree=20 depth=9
# tree=25 depth=2
# tree=25 depth=8
# tree=22 depth=2
# tree=24 depth=12
# tree=24 depth=6
# tree=25 depth=14
# tree=23 depth=4
# tree=21 depth=6
# tree=23 depth=10
# tree=27 depth=1
# tree=22 depth=14
# tree=22 depth=8
# tree=27 depth=7
# tree=21 depth=12
# tree=26 depth=5
# tree=27 depth=13
# tree=26 depth=11
# tree=24 depth=1
# tree=22 depth=3
# tree=25 depth=3
# tree=25 depth=9
# tree=24 depth=13
# tree=28 depth=4
# tree=28 depth=10
# tree=24 depth=7
# tree=23 depth=5
# tree=22 depth=15
# tree=22 depth=9
# tree=23 depth=11
# tree=25 depth=15
# tree=27 depth=2
# tree=24 depth=2
# tree=27 depth=8
# tree=29 depth=1
# tree=26 depth=6
# tree=26 depth=12
# tree=27 depth=14
# tree=29 depth=7
# tree=23 depth=6
# tree=24 depth=14
# tree=25 depth=4
# tree=24 depth=8
# tree=23 depth=12
# tree=25 depth=10
# tree=29 depth=13
# tree=28 depth=11
# tree=28 depth=5
# tree=26 depth=1
# tree=24 depth=3
# tree=30 depth=4
# tree=30 depth=10
# tree=27 depth=3
# tree=27 depth=9
# tree=26 depth=7
# tree=26 depth=13
# tree=24 depth=15
# tree=24 depth=9
# tree=27 depth=15
# tree=29 depth=2
# tree=25 depth=5
# tree=25 depth=11
# tree=29 depth=8
# tree=29 depth=14
# tree=26 depth=2
# tree=28 depth=12
# tree=28 depth=6
# tree=26 depth=8
# tree=27 depth=4
# tree=26 depth=14
# tree=27 depth=10
# tree=30 depth=5
# tree=30 depth=11
# tree=25 depth=6
# tree=28 depth=1
# tree=25 depth=12
# tree=29 depth=3
# tree=29 depth=9
# tree=26 depth=3
# tree=28 depth=13
# tree=29 depth=15
# tree=28 depth=7
# tree=26 depth=9
# tree=26 depth=15
# tree=27 depth=5
# tree=27 depth=11
# tree=30 depth=6
# tree=30 depth=12
# tree=28 depth=2
# tree=29 depth=4
# tree=29 depth=10
# tree=28 depth=14
# tree=28 depth=8
# tree=27 depth=6
# tree=30 depth=1
# tree=27 depth=12
# tree=28 depth=3
# tree=30 depth=7
# tree=29 depth=5
# tree=30 depth=13
# tree=28 depth=15
# tree=29 depth=11
# tree=28 depth=9
# tree=30 depth=2
# tree=30 depth=8
# tree=29 depth=6
# tree=30 depth=14
# tree=29 depth=12
# tree=30 depth=3
# tree=30 depth=9
# tree=30 depth=15
# [(24950.009516576596, 22409.91805173077, 1, 1), (24793.206804155, 22303.893304568366, 1, 2), (24690.69401624294, 22272.364718210545, 1, 3), (24602.83171493263, 22254.07492571524, 1, 4), (24516.803314182936, 22160.90272895537, 1, 5), (24439.878774337973, 22110.433534628202, 1, 6), (24335.60359166456, 22069.78066885455, 1, 7), (24253.239008588116, 22069.368395155132, 1, 8), (24196.798800455475, 21950.503836289947, 1, 9), (24152.860627250655, 21849.99347064122, 1, 10), (24128.25360462525, 22025.803443585417, 1, 11), (24120.947833333335, 21967.99094414414, 1, 12), (24117.63656193355, 21955.311606506497, 1, 13), (24116.572877643513, 21927.477522522517, 1, 14), (24116.192542799603, 21956.56164164164, 1, 15), (21041.02913036681, 18763.389096913277, 2, 1), (20750.34428297242, 18425.444280013005, 2, 2), (20558.704828811922, 18277.709018293193, 2, 3), (20392.567815431106, 18379.40621483453, 2, 4), (20234.92512564875, 18276.2093793735, 2, 5), (20078.90063655388, 18196.174803978167, 2, 6), (19918.46474765238, 18122.732075811, 2, 7), (19766.321068703084, 18082.37222706018, 2, 8), (19675.64236584889, 18075.090255178322, 2, 9), (19587.318112738885, 17855.041050576514, 2, 10), (19559.053333116106, 17925.876735287286, 2, 11), (19543.03317546349, 17889.95483065218, 2, 12), (19536.672696844835, 18040.804170186286, 2, 13), (19534.753528776437, 17927.17392905405, 2, 14), (19534.12340372608, 17965.186715515512, 2, 15), (17847.545300936705, 15568.50705693889, 3, 1), (17478.09050981829, 15372.59386823437, 3, 2), (17211.82438349537, 15229.479471365643, 3, 3), (16985.937825498637, 15278.447883446692, 3, 4), (16745.999234869345, 15181.812083465133, 3, 5), (16535.493226519167, 14978.178049807282, 3, 6), (16334.325996685382, 14951.10967445943, 3, 7), (16113.999961274543, 14928.473956859585, 3, 8), (16005.862711367306, 14966.132808666562, 3, 9), (15880.189363155361, 14540.298795886867, 3, 10), (15854.348304955598, 14832.681866864852, 3, 11), (15834.804236532558, 14698.940175534537, 3, 12), (15825.714828460113, 14883.373101633779, 3, 13), (15823.487914805897, 14788.04437381982, 3, 14), (15822.647395148206, 14700.597574542542, 3, 15), (15253.5965459373, 13145.523489965733, 4, 1), (14788.749449764151, 12793.401472095562, 4, 2), (14455.807509214035, 12574.396699159459, 4, 3), (14194.719572605509, 12661.309180105682, 4, 4), (13942.786631702758, 12607.783935470192, 4, 5), (13662.646336122263, 12454.476625545789, 4, 6), (13409.041513623964, 12459.22709521537, 4, 7), (13137.21810970757, 12427.952919955973, 4, 8), (13018.345187243785, 12489.379672100142, 4, 9), (12879.08136443289, 11947.436598869894, 4, 10), (12853.113467851026, 12330.371948821352, 4, 11), (12831.007018841972, 12149.135213432302, 4, 12), (12819.627708354881, 12428.4505984883, 4, 13), (12817.347556009396, 12269.273319818203, 4, 14), (12816.350866677045, 12190.995471221733, 4, 15), (13134.231041107882, 11038.316031945924, 5, 1), (12610.383191120272, 10722.81622766404, 5, 2), (12244.843041945756, 10550.220427398364, 5, 3), (11915.9329805482, 10573.763761577913, 5, 4), (11636.117738000514, 10489.83002932494, 5, 5), (11323.588617767862, 10432.889561230422, 5, 6), (11010.579012057064, 10483.383423931902, 5, 7), (10733.650242749674, 10460.231681601921, 5, 8), (10588.063131061212, 10458.569625061084, 5, 9), (10446.157902697412, 9921.490228594255, 5, 10), (10418.238629259627, 10434.24286633507, 5, 11), (10394.841098160741, 10244.294032567583, 5, 12), (10384.711790152853, 10475.909686560111, 5, 13), (10382.231012038917, 10302.648809429213, 5, 14), (10381.250408255237, 10264.115414288184, 5, 15), (11405.24733659579, 9450.993926919577, 6, 1), (10828.691246895256, 9087.419230888054, 6, 2), (10418.349501290928, 8846.684861993162, 6, 3), (10067.701532896062, 8830.074382035304, 6, 4), (9755.921129407488, 8857.26307286512, 6, 5), (9398.1045588225, 8731.26076546361, 6, 6), (9067.61996056457, 8933.817167476202, 6, 7), (8780.693190192715, 8949.022981762411, 6, 8), (8604.818525107363, 8857.185059787731, 6, 9), (8471.22 ...

# %%
from matplotlib import cm
from matplotlib import interactive
import ipympl
interactive(True)
# %matplotlib widget

mse_train_line, mse_test_line, trees_line, depth_line = zip(*result)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(np.reshape(trees_line, (tree_count, depth_count)), np.reshape(depth_line, (tree_count, depth_count)), np.reshape(mse_train_line, (tree_count, depth_count)), cmap="Blues")

ax.plot_surface(np.reshape(trees_line, (tree_count, depth_count)), np.reshape(depth_line, (tree_count, depth_count)), np.reshape(mse_test_line, (tree_count, depth_count)), cmap="Reds")

ax.set_xlabel('X trees')
ax.set_ylabel('Y depths')
ax.set_zlabel('Z mse')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Вывод: при глубине большей 2 начинается переобучение модели и падения качества, при увеличение количества деревьев точность модели увеличивается, но при при колличестве деревьев больше 20 не дает значимого прироста точности.
